# %%
import pandas as pd

# %%
data=pd.read_csv('xclara.csv')

# %%
data.head()
# Out:
#     Feature1   Feature2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
data.shape
# Out:
# (3000, 2)

# %%
import numpy as np

# %%
c1=data['Feature1'].values

# %%
c2=data['Feature2'].values

# %%
c1
# Out:
# array([ 2.072345, 17.93671 ,  1.083576, ..., 64.46532 , 90.72282 ,
#        64.87976 ])

# %%
c2
# Out:
# array([ -3.241693,  15.78481 ,   7.319176, ..., -10.50136 , -12.25584 ,
#        -24.87731 ])

# %%
df1=pd.DataFrame(c1)

# %%
df1.head()
# Out:
#            0
# 0   2.072345
# 1  17.936710
# 2   1.083576
# 3  11.120670
# 4  23.711550

# %%
from sklearn.cluster import KMeans

# %%
range_cluster=[1,2,3,5,7,10,15,20]

# %%
sse={} #Sum of squared error

# %%
for n_clusters in range_cluster:
    kmeans=KMeans(n_clusters=n_clusters)
    kmeans_label=kmeans.fit(data)
    sse[n_clusters]=kmeans_label.inertia_ #Interia = Loss

# %%
sse.keys().sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-8faaa41d8a13> in <module>()
# ----> 1 sse.keys().sort()
#
# AttributeError: 'dict_keys' object has no attribute 'sort'

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.figure()
plt.plot(list(sse.keys()),list(sse.values()))
plt.scatter(list(sse.keys()),list(sse.values()))
plt.xlabel('Number of Clusters')
plt.ylabel('Cost')
plt.show()
print(sse.keys())
# Out:
# dict_keys([1, 2, 3, 20, 5, 7, 10, 15])

# %%
plt.scatter(c1,c2,c='black')

# %%
kmeans=KMeans(n_clusters=3)

# %%
kmeans_label=kmeans.fit_predict(data)

# %%
plt.scatter(c1,c2,c=kmeans.labels_)

# %%
centroids=kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[  9.4780459 ,  10.686052  ],
#        [ 40.68362784,  59.71589274],
#        [ 69.92418447, -10.11964119]])

# %%
plt.scatter(c1,c2,c=kmeans.labels_)
h=np.array(centroids)
plt.scatter(h[:,0],h[:,1],c='red')
